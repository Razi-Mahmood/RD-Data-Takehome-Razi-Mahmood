# %%
# %reload_ext autoreload
#%load_ext autoreload
# %autoreload 2

# %% [markdown]
# ###Question 1:
# Design & build a small dataset (about 100+ images) to differentiate between real and fake face images. Please explain:
# a. Considerations that went into deciding what data to collect.
# b. How you went about collecting the data.
# c. Besides fake/real labels, what other labels would you consider? Explain a simple method to sample a uniform dataset in the i.i.d sense, given the labels.
# d. What API (e.g Pandas, etc.) you used to store and organize meta information about the dataset.
# e. Please share your mini-dataset as a zip file.

# %% [markdown]
# ### A. Considerations that went into deciding what data to collect.
#     1. The dataset should ideally show a variety of deep fake operations, i.e. synthetic, identity swapping, attribute manipulation, and expression swap
#     2. In addition, the dataset should have good demographic distribution of males, females, age distribution (young to old), different races and ethnicities.
#     3. Restricted to image datasets as per the problem specification
#     4. Was freely available with no behind firewall, paid licensing, or other such requirement.
#     5. Was not too large to fit in my computer memory

# %% [markdown]
# ## B. How data was collected
# Identified two datasets that seem to have a variety of content satisfying the requirements above.
# Faces-HQ  is a dataset that was collected by Durall et al. as described in their 2019 paper "Unmasking DeepFakes with simple Features" (https://arxiv.org/abs/1911.00686)
# Unmasking DeepFakes with simple Features
# They created a database called Faces-HQ by collecting fake and real face data from multiple sources from CelebA-HQ dataset, Flickr-Faces-HQ dataset, 100K Facesproject and www.thispersondoesnotexist.com. In total, they had collected 40K high quality images being half of them real and the other half fake faces, achieving in this manner a balanced dataset.
#
# Since this dataset had the real and fake images subdivided into categories describining the nature of the faking process, and seeming to cover the different methods of fake face generation. I chose this dataset for experimentation as I could sample from this distribution to approximate the IID requirement in part C of question 1. The dataset is available from :
# https://drive.google.com/file/d/1rokPjCHe30mZBnk7J5j0MiIuUAuOqHoQ/view
# For example, both real and fake belong to these major categories:
# exit_phone_room
# hugging_happy
# kitchen_pan
# kitchen_still
# meeting_serious
# outside_talking_pan_laughing
# outside_talking_still_laughing
# podium_speech_happy
# secret_conversation
# talking_against_wall
# talking_angry_couch
# walk_down_hall_angry
# walking_and_outside_surprised
# walking_down_indoor_hall_disgust
# walking_down_street_outside_angry
# walking_outside_cafe_disgusted
#
#
# I also examined another dataset from Kaggle contributed by Aman Chaudhary that had an interesting racial mix of faces, possibly a late entry after the DFDC challenge was over. This dataset was used to train and test the CNN model described in answer to question 3. This dataset was downloaded from https://www.kaggle.com/datasets/agcy1210/fake-and-real-image-dataset?resource=download

# %% [markdown]
# ## Besides fake/real labels, what other labels would you consider? Explain a simple method to sample a uniform dataset in the i.i.d sense, given the labels.
#
# Since the goal is to classify fake and real, these are the top level labels of interest. However, in the Faces-HQ dataset, there was further labels at finer granularity. Looking at the distribution of these finer-grained labels, as shown by the cell below, we observe that the inner class labels are unbalanced in each real and fake classes.
#
# exit_phone_room 102
# hugging_happy 187
# kitchen_pan 17
# kitchen_still 323
# meeting_serious 51
# outside_talking_pan_laughing 170
# outside_talking_still_laughing 306
# podium_speech_happy 323
# secret_conversation 85
# talking_against_wall 255
# talking_angry_couch 238
# walk_down_hall_angry 85
# walking_and_outside_surprised 85
# walking_down_indoor_hall_disgust 204
# walking_down_street_outside_angry 102
# walking_outside_cafe_disgusted 85
#
# Assuming the original data was an IID distribution, we sample the train,validate and test distributions randomly from each overall class so that the resulting incidence distributions of the inner classes remains similar to the original distributions. This type of sampling will insure the resulting splits are IID as well.

# %%
#this pre-processing was to make it easy to visualize the distribution of the datasets.
import os
import matplotlib.pyplot as plt
from collections import OrderedDict
def collect_categstats(dirname,type,namelist=None):
    hist={}
    total=0
    
    for root, dirs, files in os.walk(dirname, topdown=False):
        for name in dirs:
            if (not name.startswith(".")):
                dir=os.path.join(root, name)
                #if "real" in dir:
                for root_dir, cur_dir, files in os.walk(dir):
                   # print(files)
                    count = len(files)
                    total+=count
                #print(count,type,name)
                hist[name]=count
    print("Total number of files in ", type," = ",total)
    od = OrderedDict()
    
    for name in hist:
        if "__" in name:
            namecore=name.split("__")[1]
        else:
            namecore=name
        if namecore not in od:
            od[namecore]=hist[name]
        else:
            od[namecore]+=hist[name]
       
    if (namelist is None):
        namelist=[]
        for namecore in od:
            namelist.append(namecore)
            print(namecore,od[namecore])
    return od,namelist

#plots the distribution of categories of the raw data
def plot_hist(hist1,hist2,namelist):
    names1=[]
    values1=[]
    names2=[]
    values2=[]
    for name in namelist:
        names1.append(name)
        if name in hist1:
            values1.append(hist1[name])
        else:
            values1.append(0)
        names2.append(name)
        if name in hist2:
            values2.append(hist2[name])
        else:
            values2.append(0)
  #  for i in range(len(names1)):
  #      print(names1[i],values1[i])
   #     print(names2[i],values2[i])
   # print(len(hist1) ," keys")
    plt.subplot(1, 2, 1) # row 1, col 2 index 1
    plt.bar(range(len(names1)), values1, tick_label=names1)
    plt.title("Real face distribution")
    plt.xlabel('The categories ')
    plt.ylabel('Number of Images Per Category')
    plt.subplot(1, 2, 2) # index 2
    plt.bar(range(len(names2)), values2, tick_label=names2)
    plt.title("Fake face distribution")
    plt.xlabel('The categories ')
    plt.ylabel('Number of Images Per Category')
    plt.show()

   


od_real,namelist=collect_categstats("../data/original/real","real")
od_fake,namelist=collect_categstats("../data/original/fake","fake",namelist)

plot_hist(od_real,od_fake,namelist)
# Out:
# Total number of files in  real  =  2468
# outside_talking_still_laughing 335
# hugging_happy 180
# walking_down_street_outside_angry 44
# podium_speech_happy 342
# talking_against_wall 261
# kitchen_still 324
# walking_down_indoor_hall_disgust 186
# walking_and_outside_surprised 85
# talking_angry_couch 255
# outside_talking_pan_laughing 43
# secret_conversation 51
# walking_outside_cafe_disgusted 78
# exit_phone_room 38
# walk_down_hall_angry 32
# meeting_serious 60
# kitchen_pan 3
# Total number of files in  fake  =  1680

# %%
#This section loads the list of files into a pandas dataframe and uses random sampling to create the 100 image dataset

import pandas as pd
import shutil

#takes a listing of all files
def get_allfilelist(dirname):
    allfiles=[]
    for root, dirs, files in os.walk(dirname, topdown=False):
        for name in dirs:
            if (not name.startswith(".")):
                dir=os.path.join(root, name)
            #if "real" in dir:
                for root_dir, cur_dir, files in os.walk(dir):
                    for file in files:
                        path=root_dir+"/"+file
                        allfiles.append(path)
    return allfiles

#samples the data for the required number as per question1
def random_sampledata(dirname,num_samples,outdir):
    allfiles=get_allfilelist(dirname)
    df = pd.DataFrame(allfiles)
    dfsample=df.sample(num_samples)
    dfsample.columns=['Sample']
    print(dfsample.head())
    return dfsample

#saving renders it into a flat structure with the subclass name built into the image name to simplify the model building for question 3
def save_sampleddata(df,outdir,key):
    for ind in df.index:
        name=str(df['Sample'][ind])
       
        innername=name.split(key)[1]
        innername=innername.replace("/","__")
        
        if not os.path.exists(outdir):
            os.makedirs(outdir)
        outpath=outdir+"/"+innername
        print("Copying ",name,outpath)
        shutil.copy(name, outpath)
    
def plot_samplehistDF(df1,df2,namelist):
    
    hMap1={}
    hMap2={}
    dfindex=df1.index
   
    for ind in df1.index:
        name=str(df1['Sample'][ind])
       
        #name=str(dfcol[index])
       # print(name)
        if "__" in name:
            namecore=str(name).split("__")[1]
        else:
            namecore=str(name)
        namecore=namecore.split("/")[0]
      #  print(namecore)
        if namecore not in hMap1:
            hMap1[namecore]=1
        else:
            hMap1[namecore]+=1
    for ind in df2.index:
        name=str(df2['Sample'][ind])
        if "__" in name:
            namecore=str(name).split("__")[1]
        else:
            namecore=str(name)
        namecore=namecore.split("/")[0]
       # print(namecore)
        if namecore not in hMap2:
            hMap2[namecore]=1
        else:
            hMap2[namecore]+=1
   # print(len(hMap1),len(hMap2))
    plot_hist(hMap1,hMap2,namelist)

# %%
real_sample=random_sampledata("../data/original/real",50,"../data/sampled/real")
fake_sample=random_sampledata("../data/original/fake",50,"../data/sampled/fake")
# Out:
#                                                  Sample
# 1520  ../data/original/real/05__talking_against_wall...
# 1081  ../data/original/real/14__walk_down_hall_angry...
# 1825  ../data/original/real/06__talking_angry_couch/...
# 1238  ../data/original/real/24__outside_talking_pan_...
# 1397    ../data/original/real/21__kitchen_still/767.jpg
#                                                  Sample
# 1476  ../data/original/fake/17_08__podium_speech_hap...
# 1526  ../data/original/fake/06_18__podium_speech_hap...
# 146   ../data/original/fake/01_11__meeting_serious__...
# 1470  ../data/original/fake/17_08__podium_speech_hap...
# 464   ../data/original/fake/23_19__walking_down_indo...

# %%
plot_samplehistDF(real_sample,fake_sample,namelist)

# %%
save_sampleddata(real_sample,"../data/sampled/real","../data/original/real/")
save_sampleddata(fake_sample,"../data/sampled/fake","../data/original/fake/")
# Out:
# Copying  ../data/original/real/05__talking_against_wall/6933.jpg ../data/sampled/real/05__talking_against_wall__6933.jpg
# Copying  ../data/original/real/14__walk_down_hall_angry/682.jpg ../data/sampled/real/14__walk_down_hall_angry__682.jpg
# Copying  ../data/original/real/06__talking_angry_couch/4171.jpg ../data/sampled/real/06__talking_angry_couch__4171.jpg
# Copying  ../data/original/real/24__outside_talking_pan_laughing/3234.jpg ../data/sampled/real/24__outside_talking_pan_laughing__3234.jpg
# Copying  ../data/original/real/21__kitchen_still/767.jpg ../data/sampled/real/21__kitchen_still__767.jpg
# Copying  ../data/original/real/14__kitchen_still/2450.jpg ../data/sampled/real/14__kitchen_still__2450.jpg
# Copying  ../data/original/real/23__podium_speech_happy/6030.jpg ../data/sampled/real/23__podium_speech_happy__6030.jpg
# Copying  ../data/original/real/07__talking_against_wall/597.jpg ../data/sampled/real/07__talking_against_wall__597.jpg
# Copying  ../data/original/real/07__kitchen_still/4602.jpg ../data/sampled/real/07__kitchen_still__4602.jpg
# Copying  ../data/original/real/11__kitchen_still/655.jpg ../data/sampled/real/11__kitchen_still__655.jpg
# Copying  ../data/original/real/06__talking_angry_couch/4175.jpg ../data/sampled/real/06__talking_angry_couch__4175.jpg
# Copying  ../data/original/real/21__walking_and_outside_surprised/5758.jpg ../data/sampled/real/21__walking_and_outside_surprised__5758.jpg
# Copying  ../data/original/real/25__podium_speech_happy/6538.jpg ../data/sampled/real/25__podium_speech_happy__6538.jpg
# Copying  ../data/original/real/24__talking_against_wall/5303.jpg ../data/sampled/real/24__talking_against_wall__5303.jpg
# Copying  ../data/original/real/26__talking_angry_couch/2992.jpg ../data/sampled/real/26__talking_angry_couch__2992.jpg
# Copying  ../data/original/real/04__kitchen_still/1099.jpg ../data/sampled/real/04__kitchen_still__1099.jpg
# Copying  ../data/original/real/17__outside_talking_still_laughing/7066.jpg ../data/sampled/real/17__outside_talking_still_laughing__7066.jpg
# Copying  ../data/original/real/04__walking_down_street_outside_angry/1794.jpg ../data/sampled/real/04__walking_down_street_outside_angry__1794.jpg
# Copying  ../data/original/real/16__talking_against_wall/6578.jpg ../data/sampled/real/16__talking_against_wall__6578.jpg
# Copying  ../data/original/real/27__walking_down_indoor_hall_disgust/1713.jpg ../data/sampled/real/27__walking_down_indoor_hall_disgust__1713.jpg
# Copying  ../data/original/real/26__outside_talking_still_laughing/562.jpg ../data/sampled/real/26__outside_talking_still_laughing__562.jpg
# Copying  ../data/original/real/05__talking_against_wall/6930.jpg ../data/sampled/real/05__talking_against_wall__6930.jpg
# Copying  ../data/original/real/28__outside_talking_still_laughing/6923.jpg ../data/sampled/real/28__outside_talking_still_laughing__6923.jpg
# Copying  ../data/original/real/07__talking_angry_couch/5668.jpg ../data/sampled/real/07__talking_angry_couch__5668.jpg
# Copying  ../data/original/real/02__kitchen_still/1924.jpg ../data/sampled/real/02__kitchen_still__1924.jpg
# Copying  ../data/original/real/13__walking_outside_cafe_disgusted/2831.jpg ../data/sampled/real/13__walking_outside_cafe_disgusted__2831.jpg
# Copying  ../data/original/real/08__talking_against_wall/3261.jpg ../data/sampled/real/08__talking_against_wall__3261.jpg
# Copying  ../data/original/real/08__outside_talking_pan_laughing/4801.jpg ../data/sampled/real/08__outside_talking_pan_laughing__4801.jpg
# Copying  ../data/original/real/17__kitchen_still/7126.jpg ../data/sampled/real/17__kitchen_still__7126.jpg
# Copying  ../data/original/real/03__kitchen_still/3575.jpg ../data/sampled/real/03__kitchen_still__3575.jpg
# Copying  ../data/original/real/01__walking_and_outside_surprised/4347.jpg ../data/sampled/real/01__walking_and_outside_surprised__4347.jpg
# Copying  ../data/original/real/21__walking_down_street_outside_angry/2677.jpg ../data/sampled/real/21__walking_down_street_outside_angry__2677.jpg
# Copying  ../data/original/real/26__walking_outside_cafe_disgusted/162.jpg ../data/sampled/real/26__walking_outside_cafe_disgusted__162.jpg
# Copying  ../data/original/real/25__podium_speech_happy/6545.jpg ../data/sampled/real/25__podium_speech_happy__6545.jpg
# Copying  ../data/original/real/20__outside_talking_still_laughing/2174.jpg ../data/sampled/real/20__outside_talking_still_laughing__2174.jpg
# Copying  ../data/original/real/23__outside_talking_still_laughing/6709.jpg ../data/sampled/real/23__outside_talking_still_laughing__6709.jpg
# Copying  ../data/original/real/20__podium_speech_happy/6631.jpg ../data/sampled/real/20__podium_speech_happy__6631.jpg
# Copying  ../data/original/real/27__hugging_happy/5978.jpg ../data/sampled/real/27__hugging_happy__5978.jpg
# Copying  ../data/original/real/26__walking_outside_cafe_disgusted/163.jpg ../data/sampled/real/26__walking_outside_cafe_disgusted__163.jpg
# Copying  ../data/original/real/07__talking_angry_couch/5660.jpg ../data/sampled/real/07__talking_angry_couch__5660.jpg
# Copying  ../data/original/real/01__kitchen_still/5020.jpg ../data/sampled/real/01__kitchen_still__5020.jpg
# Copying  ../data/original/real/01__kitchen_still/5039.jpg ../data/sampled/real/01__kitchen_still__5039.jpg
# Copying  ../data/original/real/26__walking_outside_cafe_disgusted/171.jpg ../data/sampled/real/26__walking_outside_cafe_disgusted__171.jpg
# Copying  ../data/original/real/05__kitchen_still/5937.jpg ../data/sampled/real/05__kitchen_still__5937.jpg
# Copying  ../data/original/real/14__talking_angry_couch/1849.jpg ../data/sampled/real/14__talking_angry_couch__1849.jpg
# Copying  ../data/original/real/27__podium_speech_happy/221.jpg ../data/sampled/real/27__podium_speech_happy__221.jpg
# Copying  ../data/original/real/01__talking_against_wall/5448.jpg ../data/sampled/real/01__talking_against_wall__5448.jpg
# Copying  ../data/original/real/12__outside_talking_still_laughing/4001.jpg ../data/sampled/real/12__outside_talking_still_laughing__4001.jpg
# Copying  ../data/original/real/15__kitchen_still/3021.jpg ../data/sampled/real/15__kitchen_still__3021.jpg
# Copying  ../data/original/real/21__hugging_happy/5174.jpg ../data/sampled/real/21__hugging_happy__5174.jpg
# Copying  ../data/original/fake/17_08__podium_speech_happy__ISS1V0B1/3830.jpg ../data/sampled/fake/17_08__podium_speech_happy__ISS1V0B1__3830.jpg
# Copying  ../data/original/fake/06_18__podium_speech_happy__5HNHMK6G/21572.jpg ../data/sampled/fake/06_18__podium_speech_happy__5HNHMK6G__21572.jpg
# Copying  ../data/original/fake/01_11__meeting_serious__FCNL2OVP/11419.jpg ../data/sampled/fake/01_11__meeting_serious__FCNL2OVP__11419.jpg
# Copying  ../data/original/fake/17_08__podium_speech_happy__ISS1V0B1/3833.jpg ../data/sampled/fake/17_08__podium_speech_happy__ISS1V0B1__3833.jpg
# Copying  ../data/original/fake/23_19__walking_down_indoor_hall_disgust__H4SUVFTL/23421.jpg ../data/sampled/fake/23_19__walking_down_indoor_hall_disgust__H4SUVFTL__23421.jpg
# Copying  ../data/original/fake/06_27__walking_and_outside_surprised__SZWVBWY4/1591.jpg ../data/sampled/fake/06_27__walking_and_outside_surprised__SZWVBWY4__1591.jpg
# Copying  ../data/original/fake/09_27__walking_down_street_outside_angry__RC9KATOO/2864.jpg ../data/sampled/fake/09_27__walking_down_street_outside_angry__RC9KATOO__2864.jpg
# Copying  ../data/original/fake/12_26__walking_outside_cafe_disgusted__OVOQACG8/24167.jpg ../data/sampled/fake/12_26__walking_outside_cafe_disgusted__OVOQACG8__24167.jpg
# Copying  ../data/original/fake/06_25__talking_angry_couch__MI9BDQ7M/19264.jpg ../data/sampled/fake/06_25__talking_angry_couch__MI9BDQ7M__19264.jpg
# Copying  ../data/original/fake/13_09__hugging_happy__BVZGDFD8/13379.jpg ../data/sampled/fake/13_09__hugging_happy__BVZGDFD8__13379.jpg
# Copying  ../data/original/fake/25_27__walk_down_hall_angry__1KU29EUL/16898.jpg ../data/sampled/fake/25_27__walk_down_hall_angry__1KU29EUL__16898.jpg
# Copying  ../data/original/fake/11_13__outside_talking_still_laughing__61T622EK/17058.jpg ../data/sampled/fake/11_13__outside_talking_still_laughing__61T622EK__17058.jpg
# Copying  ../data/original/fake/05_08__exit_phone_room__YN1Q9TER/977.jpg ../data/sampled/fake/05_08__exit_phone_room__YN1Q9TER__977.jpg
# Copying  ../data/original/fake/27_01__talking_against_wall__ZYCZ30C0/7070.jpg ../data/sampled/fake/27_01__talking_against_wall__ZYCZ30C0__7070.jpg
# Copying  ../data/original/fake/13_25__hugging_happy__7YMTAF29/20809.jpg ../data/sampled/fake/13_25__hugging_happy__7YMTAF29__20809.jpg
# Copying  ../data/original/fake/14_18__kitchen_still__A5A1Q467/13716.jpg ../data/sampled/fake/14_18__kitchen_still__A5A1Q467__13716.jpg
# Copying  ../data/original/fake/12_13__podium_speech_happy__N8IGC93J/13752.jpg ../data/sampled/fake/12_13__podium_speech_happy__N8IGC93J__13752.jpg
# Copying  ../data/original/fake/21_14__outside_talking_still_laughing__N0WM4GSV/8638.jpg ../data/sampled/fake/21_14__outside_talking_still_laughing__N0WM4GSV__8638.jpg
# Copying  ../data/original/fake/18_04__walking_outside_cafe_disgusted__6J3ZFEJQ/10553.jpg ../data/sampled/fake/18_04__walking_outside_cafe_disgusted__6J3ZFEJQ__10553.jpg
# Copying  ../data/original/fake/18_14__podium_speech_happy__0YRBHIKG/20722.jpg ../data/sampled/fake/18_14__podium_speech_happy__0YRBHIKG__20722.jpg
# Copying  ../data/original/fake/26_09__outside_talking_still_laughing__QSE5A0GF/9229.jpg ../data/sampled/fake/26_09__outside_talking_still_laughing__QSE5A0GF__9229.jpg
# Copying  ../data/original/fake/11_13__outside_talking_still_laughing__61T622EK/17052.jpg ../data/sampled/fake/11_13__outside_talking_still_laughing__61T622EK__17052.jpg
# Copying  ../data/original/fake/27_26__talking_against_wall__IE9N0ZI9/17147.jpg ../data/sampled/fake/27_26__talking_against_wall__IE9N0ZI9__17147.jpg
# Copying  ../data/original/fake/07_03__talking_against_wall__IFSURI9X/10818.jpg ../data/sampled/fake/07_03__talking_against_wall__IFSURI9X__10818.jpg
# Copying  ../data/original/fake/06_27__walking_outside_cafe_disgusted__VN14WY2N/22826.jpg ../data/sampled/fake/06_27__walking_outside_cafe_disgusted__VN14WY2N__22826.jpg
# Copying  ../data/original/fake/21_07__talking_angry_couch__MKU99DVX/1061.jpg ../data/sampled/fake/21_07__talking_angry_couch__MKU99DVX__1061.jpg
# Copying  ../data/original/fake/07_03__talking_against_wall__IFSURI9X/10806.jpg ../data/sampled/fake/07_03__talking_against_wall__IFSURI9X__10806.jpg
# Copying  ../data/original/fake/09_27__walking_down_street_outside_angry__RC9KATOO/2867.jpg ../data/sampled/fake/09_27__walking_down_street_outside_angry__RC9KATOO__2867.jpg
# Copying  ../data/original/fake/08_28__outside_talking_still_laughing__8BC35RFU/2838.jpg ../data/sampled/fake/08_28__outside_talking_still_laughing__8BC35RFU__2838.jpg
# Copying  ../data/original/fake/09_14__outside_talking_still_laughing__FRY0IZ4R/17596.jpg ../data/sampled/fake/09_14__outside_talking_still_laughing__FRY0IZ4R__17596.jpg
# Copying  ../data/original/fake/01_04__meeting_serious__0XUW13RW/8417.jpg ../data/sampled/fake/01_04__meeting_serious__0XUW13RW__8417.jpg
# Copying  ../data/original/fake/26_03__walk_down_hall_angry__WBSXBL82/17999.jpg ../data/sampled/fake/26_03__walk_down_hall_angry__WBSXBL82__17999.jpg
# Copying  ../data/original/fake/02_15__walking_and_outside_surprised__I8G2LWD1/13595.jpg ../data/sampled/fake/02_15__walking_and_outside_surprised__I8G2LWD1__13595.jpg
# Copying  ../data/original/fake/06_25__talking_angry_couch__MI9BDQ7M/19255.jpg ../data/sampled/fake/06_25__talking_angry_couch__MI9BDQ7M__19255.jpg
# Copying  ../data/original/fake/01_11__meeting_serious__FCNL2OVP/11415.jpg ../data/sampled/fake/01_11__meeting_serious__FCNL2OVP__11415.jpg
# Copying  ../data/original/fake/14_21__walking_down_street_outside_angry__N0WM4GSV/23002.jpg ../data/sampled/fake/14_21__walking_down_street_outside_angry__N0WM4GSV__23002.jpg
# Copying  ../data/original/fake/07_03__talking_against_wall__IFSURI9X/10821.jpg ../data/sampled/fake/07_03__talking_against_wall__IFSURI9X__10821.jpg
# Copying  ../data/original/fake/18_04__walking_outside_cafe_disgusted__6J3ZFEJQ/10555.jpg ../data/sampled/fake/18_04__walking_outside_cafe_disgusted__6J3ZFEJQ__10555.jpg
# Copying  ../data/original/fake/10_19__outside_talking_still_laughing__O2IKR6YM/22635.jpg ../data/sampled/fake/10_19__outside_talking_still_laughing__O2IKR6YM__22635.jpg
# Copying  ../data/original/fake/25_27__walk_down_hall_angry__1KU29EUL/16894.jpg ../data/sampled/fake/25_27__walk_down_hall_angry__1KU29EUL__16894.jpg
# Copying  ../data/original/fake/18_02__secret_conversation__B95S4G6F/2660.jpg ../data/sampled/fake/18_02__secret_conversation__B95S4G6F__2660.jpg
# Copying  ../data/original/fake/09_27__walking_down_street_outside_angry__RC9KATOO/2858.jpg ../data/sampled/fake/09_27__walking_down_street_outside_angry__RC9KATOO__2858.jpg
# Copying  ../data/original/fake/04_13__walking_down_street_outside_angry__00T3UYOR/5700.jpg ../data/sampled/fake/04_13__walking_down_street_outside_angry__00T3UYOR__5700.jpg
# Copying  ../data/original/fake/03_14__kitchen_pan__38OVCK3X/2572.jpg ../data/sampled/fake/03_14__kitchen_pan__38OVCK3X__2572.jpg
# Copying  ../data/original/fake/13_09__hugging_happy__BVZGDFD8/13377.jpg ../data/sampled/fake/13_09__hugging_happy__BVZGDFD8__13377.jpg
# Copying  ../data/original/fake/06_02__podium_speech_happy__N8OSN8P6/10959.jpg ../data/sampled/fake/06_02__podium_speech_happy__N8OSN8P6__10959.jpg
# Copying  ../data/original/fake/06_27__walking_and_outside_surprised__SZWVBWY4/1590.jpg ../data/sampled/fake/06_27__walking_and_outside_surprised__SZWVBWY4__1590.jpg
# Copying  ../data/original/fake/09_03__talking_against_wall__8DTEGQ54/2365.jpg ../data/sampled/fake/09_03__talking_against_wall__8DTEGQ54__2365.jpg
# Copying  ../data/original/fake/01_02__meeting_serious__YVGY8LOK/15976.jpg ../data/sampled/fake/01_02__meeting_serious__YVGY8LOK__15976.jpg
# Copying  ../data/original/fake/26_04__walking_outside_cafe_disgusted__MS2MLJP1/4729.jpg ../data/sampled/fake/26_04__walking_outside_cafe_disgusted__MS2MLJP1__4729.jpg
